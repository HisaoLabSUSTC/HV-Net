# %%
import pandas as pd
import scipy.io as scio
import os
import sys
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# path_dir = '/liaoweiduo/HV-Net-datasets'  # for ubuntu server
path_dir = '//10.20.2.245/datasets/HV-Net-datasets'  # for windows

# %% [markdown]
# # Train graph
#
# ## M3

# %%
M = 3

## import data
train_data_file = f'train_log_train_data_M{M}_2.mat'
path = os.path.join(path_dir, train_data_file)
data = scio.loadmat(path)
loss = data['loss'].reshape(-1)     # [1, 100] -> [100]
time = data['time'].reshape(-1)     # [1, 100] -> [100]
epoch = np.arange(loss.shape[0])
collected_data = pd.DataFrame({'Loss': loss, 'Time': time, 'Epoch': epoch})

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Loss']], x="Epoch", y="Loss")
# fig.set_xscale('log')
fig.set_yscale('log')

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_loss_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %%
## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Time']], x="Epoch", y="Time")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_time_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## M5

# %%
M = 5

## import data
train_data_file = f'train_log_train_data_M{M}_2.mat'
path = os.path.join(path_dir, train_data_file)
data = scio.loadmat(path)
loss = data['loss'].reshape(-1)     # [1, 100] -> [100]
time = data['time'].reshape(-1)     # [1, 100] -> [100]
epoch = np.arange(loss.shape[0])
collected_data = pd.DataFrame({'Loss': loss, 'Time': time, 'Epoch': epoch})

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Loss']], x="Epoch", y="Loss")
fig.set_yscale('log')

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_loss_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %%
## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Time']], x="Epoch", y="Time")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_time_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## M8

# %%
M = 8

## import data
train_data_file = f'train_log_train_data_M{M}_2.mat'
path = os.path.join(path_dir, train_data_file)
data = scio.loadmat(path)
loss = data['loss'].reshape(-1)     # [1, 100] -> [100]
time = data['time'].reshape(-1)     # [1, 100] -> [100]
epoch = np.arange(loss.shape[0])
collected_data = pd.DataFrame({'Loss': loss, 'Time': time, 'Epoch': epoch})

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Loss']], x="Epoch", y="Loss")
fig.set_yscale('log')

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_loss_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %%
## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Time']], x="Epoch", y="Time")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_time_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## M10

# %%
M = 10

## import data
train_data_file = f'train_log_train_data_M{M}_2.mat'
path = os.path.join(path_dir, train_data_file)
data = scio.loadmat(path)
loss = data['loss'].reshape(-1)     # [1, 100] -> [100]
time = data['time'].reshape(-1)     # [1, 100] -> [100]
epoch = np.arange(loss.shape[0])
collected_data = pd.DataFrame({'Loss': loss, 'Time': time, 'Epoch': epoch})

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Loss']], x="Epoch", y="Loss")
fig.set_yscale('log')

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_loss_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %%
## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.lineplot(data=collected_data[['Epoch', 'Time']], x="Epoch", y="Time")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'train_time_M{M}_2.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# # Test graph
#
# ## M3

# %%
M = 3
collected_data = []
## import data
loss_MC, time_MC, loss_R2, time_R2 = [], [], [], []
for seed in range(20):
    test_MCR2_file = f'result_MC_R2_test_data_M{M}_{seed}.mat'
    path = os.path.join(path_dir, test_MCR2_file)
    data = scio.loadmat(path)
    loss_MC.append(data['Loss'].reshape(-1))     # [20,]
    time_MC.append(data['Time'].reshape(-1))     # [20,]
    loss_R2.append(data['Loss1'].reshape(-1))    # [20,]
    time_R2.append(data['Time1'].reshape(-1))    # [20,]

loss_MC = np.mean(np.stack(loss_MC), axis=0)     # [20,]
time_MC = np.mean(np.stack(time_MC), axis=0)     # [20,]
loss_R2 = np.mean(np.stack(loss_R2), axis=0)     # [20,]
time_R2 = np.mean(np.stack(time_R2), axis=0)     # [20,]

collected_data.append(pd.DataFrame({'Loss': loss_MC, 'Time': time_MC, 'Method': 'Point-based'}))
collected_data.append(pd.DataFrame({'Loss': loss_R2, 'Time': time_R2, 'Method': 'Line-based'}))

device = 'cpu'
loss_net, time_net = [], []
for seed in range(20):
    test_net_file = f'result_model_M{M}_2_test_data_M{M}_{seed}_{device}.mat'
    path = os.path.join(path_dir, test_net_file)
    data = scio.loadmat(path)
    loss_net.append(data['loss'].reshape(-1))
    time_net.append(data['time'].reshape(-1))

loss_net = np.mean(np.stack(loss_net), axis=0)
time_net = np.mean(np.stack(time_net), axis=0)
collected_data.append(pd.DataFrame({'Loss': loss_net, 'Time': time_net, 'Method': 'HV-Net'}, index=[0]))

collected_data = pd.concat(collected_data, ignore_index=True)

# print(collected_data)

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.scatterplot(data=collected_data, x="Time", y="Loss", hue="Method")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'test_M{M}_{device}.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## M5

# %%
M = 5
collected_data = []
## import data
loss_MC, time_MC, loss_R2, time_R2 = [], [], [], []
for seed in range(20):
    test_MCR2_file = f'result_MC_R2_test_data_M{M}_{seed}.mat'
    path = os.path.join(path_dir, test_MCR2_file)
    data = scio.loadmat(path)
    loss_MC.append(data['Loss'].reshape(-1))     # [20,]
    time_MC.append(data['Time'].reshape(-1))     # [20,]
    loss_R2.append(data['Loss1'].reshape(-1))    # [20,]
    time_R2.append(data['Time1'].reshape(-1))    # [20,]

loss_MC = np.mean(np.stack(loss_MC), axis=0)     # [20,]
time_MC = np.mean(np.stack(time_MC), axis=0)     # [20,]
loss_R2 = np.mean(np.stack(loss_R2), axis=0)     # [20,]
time_R2 = np.mean(np.stack(time_R2), axis=0)     # [20,]

collected_data.append(pd.DataFrame({'Loss': loss_MC, 'Time': time_MC, 'Method': 'Point-based'}))
collected_data.append(pd.DataFrame({'Loss': loss_R2, 'Time': time_R2, 'Method': 'Line-based'}))

device = 'cpu'
loss_net, time_net = [], []
for seed in range(20):
    test_net_file = f'result_model_M{M}_2_test_data_M{M}_{seed}_{device}.mat'
    path = os.path.join(path_dir, test_net_file)
    data = scio.loadmat(path)
    loss_net.append(data['loss'].reshape(-1))
    time_net.append(data['time'].reshape(-1))

loss_net = np.mean(np.stack(loss_net), axis=0)
time_net = np.mean(np.stack(time_net), axis=0)
collected_data.append(pd.DataFrame({'Loss': loss_net, 'Time': time_net, 'Method': 'HV-Net'}, index=[0]))

collected_data = pd.concat(collected_data, ignore_index=True)

# print(collected_data)

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.scatterplot(data=collected_data, x="Time", y="Loss", hue="Method")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'test_M{M}_{device}.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## M8

# %%
M = 8
collected_data = []
## import data
loss_MC, time_MC, loss_R2, time_R2 = [], [], [], []
for seed in range(20):
    test_MCR2_file = f'result_MC_R2_test_data_M{M}_{seed}.mat'
    path = os.path.join(path_dir, test_MCR2_file)
    data = scio.loadmat(path)
    loss_MC.append(data['Loss'].reshape(-1))     # [20,]
    time_MC.append(data['Time'].reshape(-1))     # [20,]
    loss_R2.append(data['Loss1'].reshape(-1))    # [20,]
    time_R2.append(data['Time1'].reshape(-1))    # [20,]

loss_MC = np.mean(np.stack(loss_MC), axis=0)     # [20,]
time_MC = np.mean(np.stack(time_MC), axis=0)     # [20,]
loss_R2 = np.mean(np.stack(loss_R2), axis=0)     # [20,]
time_R2 = np.mean(np.stack(time_R2), axis=0)     # [20,]

collected_data.append(pd.DataFrame({'Loss': loss_MC, 'Time': time_MC, 'Method': 'Point-based'}))
collected_data.append(pd.DataFrame({'Loss': loss_R2, 'Time': time_R2, 'Method': 'Line-based'}))

device = 'cpu'
loss_net, time_net = [], []
for seed in range(20):
    test_net_file = f'result_model_M{M}_2_test_data_M{M}_{seed}_{device}.mat'
    path = os.path.join(path_dir, test_net_file)
    data = scio.loadmat(path)
    loss_net.append(data['loss'].reshape(-1))
    time_net.append(data['time'].reshape(-1))

loss_net = np.mean(np.stack(loss_net), axis=0)
time_net = np.mean(np.stack(time_net), axis=0)
collected_data.append(pd.DataFrame({'Loss': loss_net, 'Time': time_net, 'Method': 'HV-Net'}, index=[0]))

collected_data = pd.concat(collected_data, ignore_index=True)

# print(collected_data)

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.scatterplot(data=collected_data, x="Time", y="Loss", hue="Method")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'test_M{M}_{device}.png'), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## M10

# %%
M = 10
collected_data = []
## import data
loss_MC, time_MC, loss_R2, time_R2 = [], [], [], []
for seed in range(20):
    test_MCR2_file = f'result_MC_R2_test_data_M{M}_{seed}.mat'
    path = os.path.join(path_dir, test_MCR2_file)
    data = scio.loadmat(path)
    loss_MC.append(data['Loss'].reshape(-1))     # [20,]
    time_MC.append(data['Time'].reshape(-1))     # [20,]
    loss_R2.append(data['Loss1'].reshape(-1))    # [20,]
    time_R2.append(data['Time1'].reshape(-1))    # [20,]

loss_MC = np.mean(np.stack(loss_MC), axis=0)     # [20,]
time_MC = np.mean(np.stack(time_MC), axis=0)     # [20,]
loss_R2 = np.mean(np.stack(loss_R2), axis=0)     # [20,]
time_R2 = np.mean(np.stack(time_R2), axis=0)     # [20,]

collected_data.append(pd.DataFrame({'Loss': loss_MC, 'Time': time_MC, 'Method': 'Point-based'}))
collected_data.append(pd.DataFrame({'Loss': loss_R2, 'Time': time_R2, 'Method': 'Line-based'}))

device = 'cpu'
loss_net, time_net = [], []
for seed in range(20):
    test_net_file = f'result_model_M{M}_2_test_data_M{M}_{seed}_{device}.mat'
    path = os.path.join(path_dir, test_net_file)
    data = scio.loadmat(path)
    loss_net.append(data['loss'].reshape(-1))
    time_net.append(data['time'].reshape(-1))

loss_net = np.mean(np.stack(loss_net), axis=0)
time_net = np.mean(np.stack(time_net), axis=0)
collected_data.append(pd.DataFrame({'Loss': loss_net, 'Time': time_net, 'Method': 'HV-Net'}, index=[0]))

collected_data = pd.concat(collected_data, ignore_index=True)

# print(collected_data)

## draw plot
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
plt.figure()
fig = sns.scatterplot(data=collected_data, x="Time", y="Loss", hue="Method")

## save plt
fig.get_figure().savefig(os.path.join(path_dir, 'figure', f'test_M{M}_{device}.png'), dpi=300, bbox_inches='tight')
